# %%
import pandas as pd
df =  pd.read_csv("weatherdata.csv")
df
# Out:
#     Pressure  global_radiation  temp_mean(c)  temp_min(c)  temp_max(c)  \
# 0      971.5              0.25           9.0          7.0         10.7
# 1      972.3              0.97          10.5          6.7         13.5
# 2      972.4              0.74           6.5          3.9          9.1
# 3      973.2              0.15           5.1          3.7          7.7
# 4      975.7              0.12           5.2          2.6          8.3
# 5      975.9              0.18           4.9          3.8          7.4
# 6      976.8              0.27           5.8          4.4          7.1
# 7      976.8              0.35           9.2          7.7          9.2
# 8      977.3              0.59          11.2          9.3         13.2
# 9      977.7              0.64           9.0          5.4         12.1
# 10     978.9              0.14           2.4          0.6          4.7
# 11     979.1              0.18           8.5          6.5          9.6
# ...

# %%
df.shape
# Out:
# (18, 8)

# %%
rows, columns = df.shape

# %%
rows
columns
# Out:
# 8

# %%
df.head(5)
# Out:
#    Pressure  global_radiation  temp_mean(c)  temp_min(c)  temp_max(c)  \
# 0     971.5              0.25           9.0          7.0         10.7
# 1     972.3              0.97          10.5          6.7         13.5
# 2     972.4              0.74           6.5          3.9          9.1
# 3     973.2              0.15           5.1          3.7          7.7
# 4     975.7              0.12           5.2          2.6          8.3
#
#    Wind_Speed  Wind_Bearing  normalized_label
# 0           0             0                 0
# 1           0             0                 0
# 2           0             0                 0
# 3           0             0                 0
# 4           0             0                 0

# %%
df.tail(5)
# Out:
#     Pressure  global_radiation  temp_mean(c)  temp_min(c)  temp_max(c)  \
# 13     979.7              0.31           8.9          6.8         11.0
# 14     980.6              1.01           3.5          0.6          7.1
# 15     980.7              0.20           8.6          5.6          9.6
# 16     980.9              2.12           9.5          5.5         14.8
# 17     981.1              0.71           8.9          6.5         12.3
#
#     Wind_Speed  Wind_Bearing  normalized_label
# 13           0             0                 0
# 14           0             0                 0
# 15           0             0                 0
# 16           0             0                 1
# 17           0             0                 0

# %%
# suppose we want particular number of rows and columns 
df[2:5]
# Out:
#    Pressure  global_radiation  temp_mean(c)  temp_min(c)  temp_max(c)  \
# 2     972.4              0.74           6.5          3.9          9.1
# 3     973.2              0.15           5.1          3.7          7.7
# 4     975.7              0.12           5.2          2.6          8.3
#
#    Wind_Speed  Wind_Bearing  normalized_label
# 2           0             0                 0
# 3           0             0                 0
# 4           0             0                 0

# %%
df.columns
# Out:
# Index(['Pressure', 'global_radiation', 'temp_mean(c)', 'temp_min(c)',
#        'temp_max(c)', 'Wind_Speed', 'Wind_Bearing', 'normalized_label'],
#       dtype='object')

# %%
# if we want the items under particualr column heading teh us ethe following method 
df['Pressure']  # or df.Pressure
# Out:
# 0     971.5
# 1     972.3
# 2     972.4
# 3     973.2
# 4     975.7
# 5     975.9
# 6     976.8
# 7     976.8
# 8     977.3
# 9     977.7
# 10    978.9
# 11    979.1
# 12    979.2
# 13    979.7
# 14    980.6
# 15    980.7
# 16    980.9
# 17    981.1
# Name: Pressure, dtype: float64

# %%
type(df['Pressure'])
# Out:
# pandas.core.series.Series

# %%
# if we wnat to print the limited columns  then we can use 

df[['Pressure','global_radiation']]
# Out:
#     Pressure  global_radiation
# 0      971.5              0.25
# 1      972.3              0.97
# 2      972.4              0.74
# 3      973.2              0.15
# 4      975.7              0.12
# 5      975.9              0.18
# 6      976.8              0.27
# 7      976.8              0.35
# 8      977.3              0.59
# 9      977.7              0.64
# 10     978.9              0.14
# 11     979.1              0.18
# 12     979.2              0.86
# 13     979.7              0.31
# 14     980.6              1.01
# 15     980.7              0.20
# 16     980.9              2.12
# 17     981.1              0.71

# %%
df
# Out:
#     Pressure  global_radiation  temp_mean(c)  temp_min(c)  temp_max(c)  \
# 0      971.5              0.25           9.0          7.0         10.7
# 1      972.3              0.97          10.5          6.7         13.5
# 2      972.4              0.74           6.5          3.9          9.1
# 3      973.2              0.15           5.1          3.7          7.7
# 4      975.7              0.12           5.2          2.6          8.3
# 5      975.9              0.18           4.9          3.8          7.4
# 6      976.8              0.27           5.8          4.4          7.1
# 7      976.8              0.35           9.2          7.7          9.2
# 8      977.3              0.59          11.2          9.3         13.2
# 9      977.7              0.64           9.0          5.4         12.1
# 10     978.9              0.14           2.4          0.6          4.7
# 11     979.1              0.18           8.5          6.5          9.6
# ...

# %% [markdown]
# ### Some operation with data framne

# %%
df['Pressure'].max()
# Out:
# np.float64(981.1)

# %%
float(df['Pressure'].mean())

# or df['Preessure'].mean()
# Out:
# 977.2111111111111

# %%
# df['Pressure'].min()
float(df['Pressure'].min())
# Out:
# 971.5

# %%
float(df['Pressure'].std())
# Out:
# 3.1577894145949914

# %%
# Printing the stat of the data set quickly
df.describe()
# Out:
#          Pressure  global_radiation  temp_mean(c)  temp_min(c)  temp_max(c)  \
# count   18.000000         18.000000     18.000000    18.000000    18.000000
# mean   977.211111          0.543889      7.616667     5.244444    10.055556
# std      3.157789          0.496756      2.567730     2.390231     2.778536
# min    971.500000          0.120000      2.400000     0.600000     4.700000
# 25%    975.750000          0.185000      5.350000     3.825000     7.850000
# 50%    977.500000          0.330000      8.750000     5.550000     9.600000
# 75%    979.575000          0.732500      9.150000     6.775000    12.250000
# max    981.100000          2.120000     11.200000     9.300000    14.800000
#
#        Wind_Speed  Wind_Bearing  normalized_label
# count        18.0          18.0         18.000000
# mean          0.0           0.0          0.166667
# std           0.0           0.0          0.383482
# min           0.0           0.0          0.000000
# ...

# %%
df [df.global_radiation>=1]
# Out:
#     Pressure  global_radiation  temp_mean(c)  temp_min(c)  temp_max(c)  \
# 14     980.6              1.01           3.5          0.6          7.1
# 16     980.9              2.12           9.5          5.5         14.8
#
#     Wind_Speed  Wind_Bearing  normalized_label
# 14           0             0                 0
# 16           0             0                 1

# %%
df[df.global_radiation==df.global_radiation.max()]
# df[df.global_radiation==df['global_radiation'].max()]  # comma seperated data then use this
# Out:
#     Pressure  global_radiation  temp_mean(c)  temp_min(c)  temp_max(c)  \
# 16     980.9              2.12           9.5          5.5         14.8
#
#     Wind_Speed  Wind_Bearing  normalized_label
# 16           0             0                 1

# %%
#  if you dont want all  the columns then you can mention wehatever you wants
df[['Pressure','global_radiation']][df.global_radiation==df.global_radiation.max()]
# Out:
#     Pressure  global_radiation
# 16     980.9              2.12

# %%
import pandas as pd

# %%
df = pd.read_csv('weather_data.csv')
df
# Out:
#          Day  Temperature   event  Wind speed
# 0   1/4/2026            26  Rainy           6
# 1   2/4/2026            35  Sunny           7
# 2   3/4/2026            46  Sunny           4
# 3   4/4/2026            32  Sunny           5
# 4   5/4/2026            28   Snow           7
# 5   6/4/2026            34  Sunny           5
# 6   7/4/2026            30  Rainy           6
# 7   8/4/2026            27   Snow           7
# 8   9/4/2026            38  Sunny           5
# 9  10/4/2026            31  Rainy           4

# %%
df.columns
# Out:
# Index(['Day', 'Temperature ', 'event', 'Wind speed'], dtype='str')

# %%
df.set_index('Day',inplace=True)
df
# Out:
#            Temperature   event  Wind speed
# Day
# 1/4/2026             26  Rainy           6
# 2/4/2026             35  Sunny           7
# 3/4/2026             46  Sunny           4
# 4/4/2026             32  Sunny           5
# 5/4/2026             28   Snow           7
# 6/4/2026             34  Sunny           5
# 7/4/2026             30  Rainy           6
# 8/4/2026             27   Snow           7
# 9/4/2026             38  Sunny           5
# 10/4/2026            31  Rainy           4

# %%
df.loc['4/4/2026']

# by this method you can view any of the row details
# Out:
# Temperature        32
# event           Sunny
# Wind speed          5
# Name: 4/4/2026, dtype: object

# %%
df.reset_index(inplace= True)

# %%
df.set_index('event',inplace=True)

# %%
df.loc['Snow']
# Out:
#             Day  Temperature   Wind speed
# event
# Snow   5/4/2026            28           7
# Snow   8/4/2026            27           7

# %%
df.reset_index(inplace=True)

# %%
df.set_index('Wind speed',inplace=True)
df
# Out:
#             index        Day  Temperature   event
# Wind speed
# 6               0   1/4/2026            26  Rainy
# 7               1   2/4/2026            35  Sunny
# 4               2   3/4/2026            46  Sunny
# 5               3   4/4/2026            32  Sunny
# 7               4   5/4/2026            28   Snow
# 5               5   6/4/2026            34  Sunny
# 6               6   7/4/2026            30  Rainy
# 7               7   8/4/2026            27   Snow
# 5               8   9/4/2026            38  Sunny
# 4               9  10/4/2026            31  Rainy

# %%
df.index
# Out:
# RangeIndex(start=0, stop=18, step=1)
